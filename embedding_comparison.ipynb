# %%
import pandas as pd
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer 
import spacy
from dask import delayed, compute
from dask.distributed import Client

# %%
corpus = pd.read_json('indian_foreign_policy_text.json')

# %%
corpus = corpus.loc[(corpus['office'] != 'President') &
                   corpus['year'].isin(list(range(1948, 2020)))]

# %%
stopwords = pd.read_csv('stopwords.csv')['stopwords'].to_list()

# %%
ccodes = pd.read_csv('ccodes.csv')

# %%
ccodes = ccodes.filter(regex = '\.en')

# %%
ccodes['country.name.en.regex'] = ccodes['country.name.en.regex'].str.replace('\\', '\\\\')
# Out:
# C:\Users\Ben\anaconda3\envs\embed\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.

# %%
ccodes['country.name.en.regex'] = '(' + ccodes['country.name.en.regex'] + '){i<=5,d<=5,e<=5}'

# %%
ccode_dict = dict(zip(ccodes['country.name.en.regex'], ccodes['country.name.en']))

# %%
ccode_dict
# Out:
# {'(afghan){i<=5,d<=5,e<=5}': 'Afghanistan',
#  '(^[å|a]land){i<=5,d<=5,e<=5}': 'Åland Islands',
#  '(albania){i<=5,d<=5,e<=5}': 'Albania',
#  '(algeria){i<=5,d<=5,e<=5}': 'Algeria',
#  '(^(?=.*americ).*samoa){i<=5,d<=5,e<=5}': 'American Samoa',
#  '(andorra){i<=5,d<=5,e<=5}': 'Andorra',
#  '(angola){i<=5,d<=5,e<=5}': 'Angola',
#  '(anguill?a){i<=5,d<=5,e<=5}': 'Anguilla',
#  '(antarctica){i<=5,d<=5,e<=5}': 'Antarctica',
#  '(antigua){i<=5,d<=5,e<=5}': 'Antigua & Barbuda',
#  '(argentin){i<=5,d<=5,e<=5}': 'Argentina',
#  '(armenia){i<=5,d<=5,e<=5}': 'Armenia',
#  '(^(?!.*bonaire).*\\\\baruba){i<=5,d<=5,e<=5}': 'Aruba',
#  '(australia){i<=5,d<=5,e<=5}': 'Australia',
#  '(^(?!.*hungary).*austria|\\\\baustri.*\\\\bemp){i<=5,d<=5,e<=5}': 'Austria',
#  '(austria-hungary){i<=5,d<=5,e<=5}': 'Austria-Hungary',
#  '(azerbaijan){i<=5,d<=5,e<=5}': 'Azerbaijan',
#  '(baden){i<=5,d<=5,e<=5}': 'Baden',
#  '(bahamas){i<=5,d<=5,e<=5}': 'Bahamas',
#  '(bahrain){i<=5,d<=5,e<=5}': 'Bahrain',
#  '(bangladesh|^(?=.*east).*paki?stan){i<=5,d<=5,e<=5}': 'Bangladesh',
#  '(barbados){i<=5,d<=5,e<=5}': 'Barbados',
#  '(bavaria){i<=5,d<=5,e<=5}': 'Bavaria',
#  '(belarus|byelo){i<=5,d<=5,e<=5}': 'Belarus',
#  '(^(?!.*luxem).*belgium){i<=5,d<=5,e<=5}': 'Belgium',
#  '(belize|^(?=.*british).*honduras){i<=5,d<=5,e<=5}': 'Belize',
#  '(benin|dahome){i<=5,d<=5,e<=5}': 'Benin',
#  '(bermuda){i<=5,d<=5,e<=5}': 'Bermuda',
#  '(bhutan){i<=5,d<=5,e<=5}': 'Bhutan',
#  '(bolivia){i<=5,d<=5,e<=5}': 'Bolivia',
#  '(herzegovina|bosnia){i<=5,d<=5,e<=5}': 'Bosnia & Herzegovina',
#  '(botswana|bechuana){i<=5,d<=5,e<=5}': 'Botswana',
#  '(bouvet){i<=5,d<=5,e<=5}': 'Bouvet Island',
#  '(brazil){i<=5,d<=5,e<=5}': 'Brazil',
#  '(british.?indian.?ocean){i<=5,d<=5,e<=5}': 'British Indian Ocean Territory',
#  '(^(?=.*\\\\bu\\\\.?\\\\s?k).*virgin|^(?=.*brit).*virgin|^(?=.*kingdom).*virgin){i<=5,d<=5,e<=5}': 'British Virgin Islands',
#  '(brunei){i<=5,d<=5,e<=5}': 'Brunei',
#  '(brunswick){i<=5,d<=5,e<=5}': 'Brunswick',
#  '(bulgaria){i<=5,d<=5,e<=5}': 'Bulgaria',
#  '(burkina|\\\\bfaso|upper.?volta){i<=5,d<=5,e<=5}': 'Burkina Faso',
#  '(burundi){i<=5,d<=5,e<=5}': 'Burundi',
#  '(cambodia|kampuchea|khmer){i<=5,d<=5,e<=5}': 'Cambodia',
#  '(cameroon){i<=5,d<=5,e<=5}': 'Cameroon',
#  '(canada){i<=5,d<=5,e<=5}': 'Canada',
#  '(verde){i<=5,d<=5,e<=5}': 'Cape Verde',
#  '(^(?=.*bonaire).*eustatius|^(?=.*carib).*netherlands|\\\\bbes.?islands){i<=5,d<=5,e<=5}': 'Caribbean Netherlands',
#  '(cayman){i<=5,d<=5,e<=5}': 'Cayman Islands',
#  '(\\\\bcentral.african.rep){i<=5,d<=5,e<=5}': 'Central African Republic',
#  '(\\\\bchad){i<=5,d<=5,e<=5}': 'Chad',
#  '(\\\\bchannel.islands){i<=5,d<=5,e<=5}': 'Channel Islands',
#  '(\\\\bchile){i<=5,d<=5,e<=5}': 'Chile',
#  '(^(?!.*\\\\bmac)(?!.*\\\\bhong)(?!.*\\\\btai)(?!.*\\\\brep).*china|^(?=.*peo)(?=.*rep).*china){i<=5,d<=5,e<=5}': 'China',
#  '(christmas){i<=5,d<=5,e<=5}': 'Christmas Island',
#  '(\\\\bcocos|keeling){i<=5,d<=5,e<=5}': 'Cocos (Keeling) Islands',
#  '(colombia){i<=5,d<=5,e<=5}': 'Colombia',
#  '(comoro){i<=5,d<=5,e<=5}': 'Comoros',
#  '(^(?!.*\\\\bd.m)(?!.*\\\\bd[\\\\.]?r)(?!.*kinshasa)(?!.*zaire)(?!.*belg)(?!.*l.opoldville)(?!.*free).*\\\\bcongo){i<=5,d<=5,e<=5}': 'Congo - Brazzaville',
#  '(\\\\bd.m.*congo|congo.*\\\\bd.m|congo.*\\\\bd[\\\\.]?r|\\\\bd[\\\\.]?r.*congo|belgian.?congo|congo.?free.?state|kinshasa|zaire|l.opoldville|drc|droc|rdc){i<=5,d<=5,e<=5}': 'Congo - Kinshasa',
#  '(\\\\bcook){i<=5,d<=5,e<=5}': 'Cook Islands',
#  '(costa.?rica){i<=5,d<=5,e<=5}': 'Costa Rica',
#  '(ivoire|ivory){i<=5,d<=5,e<=5}': 'Côte d’Ivoire',
#  '(croatia){i<=5,d<=5,e<=5}': 'Croatia',
#  '(\\\\bcuba){i<=5,d<=5,e<=5}': 'Cuba',
#  '(^(?!.*bonaire).*\\\\bcura(c|ç)ao){i<=5,d<=5,e<=5}': 'Curaçao',
#  '(cyprus){i<=5,d<=5,e<=5}': 'Cyprus',
#  '(^(?=.*rep).*czech|czechia|bohemia){i<=5,d<=5,e<=5}': 'Czechia',
#  '(czechoslovakia){i<=5,d<=5,e<=5}': 'Czechoslovakia',
#  '(denmark){i<=5,d<=5,e<=5}': 'Denmark',
#  '(djibouti){i<=5,d<=5,e<=5}': 'Djibouti',
#  '(dominica(?!n)){i<=5,d<=5,e<=5}': 'Dominica',
#  '(dominican.rep){i<=5,d<=5,e<=5}': 'Dominican Republic',
#  '(ecuador){i<=5,d<=5,e<=5}': 'Ecuador',
#  '(egypt){i<=5,d<=5,e<=5}': 'Egypt',
#  '(el.?salvador){i<=5,d<=5,e<=5}': 'El Salvador',
#  '(guine.*eq|eq.*guine|^(?=.*span).*guinea){i<=5,d<=5,e<=5}': 'Equatorial Guinea',
#  '(eritrea){i<=5,d<=5,e<=5}': 'Eritrea',
#  '(estonia){i<=5,d<=5,e<=5}': 'Estonia',
#  '(swaziland|eswatini){i<=5,d<=5,e<=5}': 'Eswatini',
#  '(ethiopia|abyssinia){i<=5,d<=5,e<=5}': 'Ethiopia',
#  '(falkland|malvinas){i<=5,d<=5,e<=5}': 'Falkland Islands',
#  '(faroe|faeroe){i<=5,d<=5,e<=5}': 'Faroe Islands',
#  '(fiji){i<=5,d<=5,e<=5}': 'Fiji',
#  '(finland){i<=5,d<=5,e<=5}': 'Finland',
#  '(^(?!.*\\\\bdep)(?!.*martinique).*france|french.?republic|\\\\bgaul){i<=5,d<=5,e<=5}': 'France',
#  '(french.?gu(y|i)ana){i<=5,d<=5,e<=5}': 'French Guiana',
#  '(french.?polynesia|tahiti){i<=5,d<=5,e<=5}': 'French Polynesia',
#  '(french.?southern){i<=5,d<=5,e<=5}': 'French Southern Territories',
#  '(gabon){i<=5,d<=5,e<=5}': 'Gabon',
#  '(gambia){i<=5,d<=5,e<=5}': 'Gambia',
#  '(^(?!.*south).*georgia){i<=5,d<=5,e<=5}': 'Georgia',
#  '(german.?democratic.?rep|democratic.?rep.*germany|east.germany|germany.*east){i<=5,d<=5,e<=5}': 'German Democratic Republic',
#  '(^(?!.*east).*germany|^(?=.*\\\\bfed.*\\\\brep).*german){i<=5,d<=5,e<=5}': 'Germany',
#  '(ghana|gold.?coast){i<=5,d<=5,e<=5}': 'Ghana',
#  '(gibraltar){i<=5,d<=5,e<=5}': 'Gibraltar',
#  '(greece|hellenic|hellas){i<=5,d<=5,e<=5}': 'Greece',
#  '(greenland){i<=5,d<=5,e<=5}': 'Greenland',
#  '(grenada){i<=5,d<=5,e<=5}': 'Grenada',
#  '(guadeloupe){i<=5,d<=5,e<=5}': 'Guadeloupe',
#  '(\\\\bguam){i<=5,d<=5,e<=5}': 'Guam',
#  '(guatemala){i<=5,d<=5,e<=5}': 'Guatemala',
#  '(guernsey){i<=5,d<=5,e<=5}': 'Guernsey',
#  '(^(?!.*eq)(?!.*span)(?!.*bissau)(?!.*portu)(?!.*new).*guinea){i<=5,d<=5,e<=5}': 'Guinea',
#  '(bissau|^(?=.*portu).*guinea){i<=5,d<=5,e<=5}': 'Guinea-Bissau',
#  '(^guyana|british.?gu(y|i)ana){i<=5,d<=5,e<=5}': 'Guyana',
#  '(haiti){i<=5,d<=5,e<=5}': 'Haiti',
#  '(hamburg){i<=5,d<=5,e<=5}': 'Hamburg',
#  '(hanover){i<=5,d<=5,e<=5}': 'Hanover',
#  '(heard.*mcdonald){i<=5,d<=5,e<=5}': 'Heard & McDonald Islands',
#  '(hesse.*lectoral){i<=5,d<=5,e<=5}': 'Hesse Electoral',
#  '(hess.*gran.*ducal){i<=5,d<=5,e<=5}': 'Hesse Grand Ducal',
#  '(hesse.darmstadt){i<=5,d<=5,e<=5}': 'Hesse-Darmstadt',
#  '(hesse.kassel){i<=5,d<=5,e<=5}': 'Hesse-Kassel',
#  '(^(?!.*brit).*honduras){i<=5,d<=5,e<=5}': 'Honduras',
#  '(hong.?kong){i<=5,d<=5,e<=5}': 'Hong Kong SAR China',
#  '(^(?!.*austr).*hungary){i<=5,d<=5,e<=5}': 'Hungary',
#  '(iceland){i<=5,d<=5,e<=5}': 'Iceland',
#  '(india(?!.*ocea)){i<=5,d<=5,e<=5}': 'India',
#  '(indonesia){i<=5,d<=5,e<=5}': 'Indonesia',
#  '(\\\\biran|persia){i<=5,d<=5,e<=5}': 'Iran',
#  '(\\\\biraq|mesopotamia){i<=5,d<=5,e<=5}': 'Iraq',
#  '(^(?!.*north).*\\\\bireland){i<=5,d<=5,e<=5}': 'Ireland',
#  '(^(?=.*isle).*\\\\bman){i<=5,d<=5,e<=5}': 'Isle of Man',
#  '(israel){i<=5,d<=5,e<=5}': 'Israel',
#  '(italy){i<=5,d<=5,e<=5}': 'Italy',
#  '(jamaica){i<=5,d<=5,e<=5}': 'Jamaica',
#  '(japan){i<=5,d<=5,e<=5}': 'Japan',
#  '(jersey){i<=5,d<=5,e<=5}': 'Jersey',
#  '(jordan){i<=5,d<=5,e<=5}': 'Jordan',
#  '(kazak){i<=5,d<=5,e<=5}': 'Kazakhstan',
#  '(kenya|british.?east.?africa|east.?africa.?prot){i<=5,d<=5,e<=5}': 'Kenya',
#  '(kiribati){i<=5,d<=5,e<=5}': 'Kiribati',
#  '(kosovo){i<=5,d<=5,e<=5}': 'Kosovo',
#  '(kuwait){i<=5,d<=5,e<=5}': 'Kuwait',
#  '(kyrgyz|kirghiz){i<=5,d<=5,e<=5}': 'Kyrgyzstan',
#  '(\\\\blaos?\\\\b){i<=5,d<=5,e<=5}': 'Laos',
#  '(latvia){i<=5,d<=5,e<=5}': 'Latvia',
#  '(lebanon){i<=5,d<=5,e<=5}': 'Lebanon',
#  '(lesotho|basuto){i<=5,d<=5,e<=5}': 'Lesotho',
#  '(liberia){i<=5,d<=5,e<=5}': 'Liberia',
#  '(libya){i<=5,d<=5,e<=5}': 'Libya',
#  '(liechtenstein){i<=5,d<=5,e<=5}': 'Liechtenstein',
#  '(lithuania){i<=5,d<=5,e<=5}': 'Lithuania',
#  '(^(?!.*belg).*luxem){i<=5,d<=5,e<=5}': 'Luxembourg',
#  '(maca(o|u)){i<=5,d<=5,e<=5}': 'Macao SAR China',
#  '(madagascar|malagasy){i<=5,d<=5,e<=5}': 'Madagascar',
#  '(malawi|nyasa){i<=5,d<=5,e<=5}': 'Malawi',
#  '(malaysia){i<=5,d<=5,e<=5}': 'Malaysia',
#  '(maldive){i<=5,d<=5,e<=5}': 'Maldives',
#  '(\\\\bmali\\\\b){i<=5,d<=5,e<=5}': 'Mali',
#  '(\\\\bmalta){i<=5,d<=5,e<=5}': 'Malta',
#  '(marshall){i<=5,d<=5,e<=5}': 'Marshall Islands',
#  '(martinique){i<=5,d<=5,e<=5}': 'Martinique',
#  '(mauritania){i<=5,d<=5,e<=5}': 'Mauritania',
#  '(mauritius){i<=5,d<=5,e<=5}': 'Mauritius',
#  '(\\\\bmayotte){i<=5,d<=5,e<=5}': 'Mayotte',
#  '(mecklenbur.*schwerin){i<=5,d<=5,e<=5}': 'Mecklenburg Schwerin',
#  '(\\\\bmexic){i<=5,d<=5,e<=5}': 'Mexico',
#  '(fed.*micronesia|micronesia.*fed){i<=5,d<=5,e<=5}': 'Micronesia (Federated States of)',
#  '(modena){i<=5,d<=5,e<=5}': 'Modena',
#  '(moldov|b(a|e)ssarabia){i<=5,d<=5,e<=5}': 'Moldova',
#  '(monaco){i<=5,d<=5,e<=5}': 'Monaco',
#  '(mongolia){i<=5,d<=5,e<=5}': 'Mongolia',
#  '(^(?!.*serbia).*montenegro){i<=5,d<=5,e<=5}': 'Montenegro',
#  '(montserrat){i<=5,d<=5,e<=5}': 'Montserrat',
#  '(morocco|\\\\bmaroc){i<=5,d<=5,e<=5}': 'Morocco',
#  '(mozambique){i<=5,d<=5,e<=5}': 'Mozambique',
#  '(myanmar|burma){i<=5,d<=5,e<=5}': 'Myanmar (Burma)',
#  '(namibia){i<=5,d<=5,e<=5}': 'Namibia',
#  '(nassau){i<=5,d<=5,e<=5}': 'Nassau',
#  '(nauru){i<=5,d<=5,e<=5}': 'Nauru',
#  '(nepal){i<=5,d<=5,e<=5}': 'Nepal',
#  '(^(?!.*\\\\bant)(?!.*\\\\bcarib).*netherlands){i<=5,d<=5,e<=5}': 'Netherlands',
#  '(netherlands.antil|dutch.antil){i<=5,d<=5,e<=5}': 'Netherlands Antilles',
#  '(new.?caledonia){i<=5,d<=5,e<=5}': 'New Caledonia',
#  '(new.?zealand){i<=5,d<=5,e<=5}': 'New Zealand',
#  '(nicaragua){i<=5,d<=5,e<=5}': 'Nicaragua',
#  '(\\\\bniger(?!ia)){i<=5,d<=5,e<=5}': 'Niger',
#  '(nigeria){i<=5,d<=5,e<=5}': 'Nigeria',
#  '(niue){i<=5,d<=5,e<=5}': 'Niue',
#  '(norfolk){i<=5,d<=5,e<=5}': 'Norfolk Island',
#  '(dprk|d.p.r.k|korea.+(d.p.r|dpr|north|dem.*rep.*)|(d.p.r|dpr|north|dem.*rep.*).+korea){i<=5,d<=5,e<=5}': 'North Korea',
#  '(macedonia|fyrom){i<=5,d<=5,e<=5}': 'North Macedonia',
#  '(mariana){i<=5,d<=5,e<=5}': 'Northern Mariana Islands',
#  '(norway){i<=5,d<=5,e<=5}': 'Norway',
#  '(oldenburg){i<=5,d<=5,e<=5}': 'Oldenburg',
#  '(\\\\boman|trucial){i<=5,d<=5,e<=5}': 'Oman',
#  '(orange.free.state){i<=5,d<=5,e<=5}': 'Orange Free State',
#  '(^(?!.*east).*paki?stan){i<=5,d<=5,e<=5}': 'Pakistan',
#  '(palau){i<=5,d<=5,e<=5}': 'Palau',
#  '(palestin|\\\\bgaza|west.?bank){i<=5,d<=5,e<=5}': 'Palestinian Territories',
#  '(panama){i<=5,d<=5,e<=5}': 'Panama',
#  '(papua|new.?guinea){i<=5,d<=5,e<=5}': 'Papua New Guinea',
#  '(paraguay){i<=5,d<=5,e<=5}': 'Paraguay',
#  '(parma){i<=5,d<=5,e<=5}': 'Parma',
#  '(peru){i<=5,d<=5,e<=5}': 'Peru',
#  '(philippines){i<=5,d<=5,e<=5}': 'Philippines',
#  '(piedmont.sardinia){i<=5,d<=5,e<=5}': 'Piedmont-Sardinia',
#  '(pitcairn){i<=5,d<=5,e<=5}': 'Pitcairn Islands',
#  '(poland){i<=5,d<=5,e<=5}': 'Poland',
#  '(portugal){i<=5,d<=5,e<=5}': 'Portugal',
#  '(prussia){i<=5,d<=5,e<=5}': 'Prussia',
#  '(puerto.?rico){i<=5,d<=5,e<=5}': 'Puerto Rico',
#  '(qatar){i<=5,d<=5,e<=5}': 'Qatar',
#  '(^republic.of.viet.?nam|south.viet.?nam|viet.?nam.south){i<=5,d<=5,e<=5}': 'Republic of Vietnam',
#  '(r(e|é)union){i<=5,d<=5,e<=5}': 'Réunion',
#  '(r(o|u|ou)mania){i<=5,d<=5,e<=5}': 'Romania',
#  '(\\\\brussia|soviet.?union|u\\\\.?s\\\\.?s\\\\.?r|socialist.?republics){i<=5,d<=5,e<=5}': 'Russia',
#  '(rwanda){i<=5,d<=5,e<=5}': 'Rwanda',
#  '(saint.martin.*FR|^(?=.*collectivity).*martin|^(?=.*france).*martin(?!ique)|^(?=.*french).*martin(?!ique)){i<=5,d<=5,e<=5}': 'Saint Martin (French part)',
#  '(^(?!.*amer).*samoa){i<=5,d<=5,e<=5}': 'Samoa',
#  '(san.?marino){i<=5,d<=5,e<=5}': 'San Marino',
#  '(\\\\bs(a|ã)o.?tom(e|é)){i<=5,d<=5,e<=5}': 'São Tomé & Príncipe',
#  '(^(?!.*piedmont)(?!.*italy).*\\\\bsardinia){i<=5,d<=5,e<=5}': 'Sardinia',
#  '(\\\\bsa\\\\w*.?arabia){i<=5,d<=5,e<=5}': 'Saudi Arabia',
#  '(saxe.weimar.eisenach){i<=5,d<=5,e<=5}': 'Saxe-Weimar-Eisenach',
#  '(saxony){i<=5,d<=5,e<=5}': 'Saxony',
#  '(senegal){i<=5,d<=5,e<=5}': 'Senegal',
#  '(^(?!.*monte).*serbia){i<=5,d<=5,e<=5}': 'Serbia',
#  '(serbia.and.montenegro){i<=5,d<=5,e<=5}': 'Serbia and Montenegro',
#  '(seychell){i<=5,d<=5,e<=5}': 'Seychelles',
#  '(sierra){i<=5,d<=5,e<=5}': 'Sierra Leone',
#  '(singapore){i<=5,d<=5,e<=5}': 'Singapore',
#  '(^(?!.*martin)(?!.*saba).*maarten){i<=5,d<=5,e<=5}': 'Sint Maarten',
#  '(^(?!.*cze).*slovak){i<=5,d<=5,e<=5}': 'Slovakia',
#  '(slovenia){i<=5,d<=5,e<=5}': 'Slovenia',
#  '(solomon){i<=5,d<=5,e<=5}': 'Solomon Islands',
#  '(somalia){i<=5,d<=5,e<=5}': 'Somalia',
#  '(somaliland){i<=5,d<=5,e<=5}': 'Somaliland',
#  '(south.africa|s\\\\\\\\..?africa){i<=5,d<=5,e<=5}': 'South Africa',
#  '(south.?georgia|sandwich){i<=5,d<=5,e<=5}': 'South Georgia & South Sandwich Islands',
#  '(^(?!.*d.*p.*r)(?!.*democrat)(?!.*dem.*rep)(?!.*people)(?!.*north).*\\\\bkorea(?!.*d.*p.*r)(?!.*dem.*rep)){i<=5,d<=5,e<=5}': 'South Korea',
#  '(\\\\bs\\\\w*.?sudan){i<=5,d<=5,e<=5}': 'South Sudan',
#  '(spain){i<=5,d<=5,e<=5}': 'Spain',
#  '(sri.?lanka|ceylon){i<=5,d<=5,e<=5}': 'Sri Lanka',
#  '(barth(e|é)lemy){i<=5,d<=5,e<=5}': 'St. Barthélemy',
#  '(helena){i<=5,d<=5,e<=5}': 'St. Helena',
#  '(kitts|\\\\bnevis){i<=5,d<=5,e<=5}': 'St. Kitts & Nevis',
#  '(\\\\blucia){i<=5,d<=5,e<=5}': 'St. Lucia',
#  '(miquelon){i<=5,d<=5,e<=5}': 'St. Pierre & Miquelon',
#  '(vincent){i<=5,d<=5,e<=5}': 'St. Vincent & Grenadines',
#  '(^(?!.*\\\\bs(?!u)).*sudan){i<=5,d<=5,e<=5}': 'Sudan',
#  '(surinam|dutch.?gu(y|i)ana){i<=5,d<=5,e<=5}': 'Suriname',
#  '(svalbard){i<=5,d<=5,e<=5}': 'Svalbard & Jan Mayen',
#  '(sweden){i<=5,d<=5,e<=5}': 'Sweden',
#  '(switz|swiss){i<=5,d<=5,e<=5}': 'Switzerland',
#  '(syria){i<=5,d<=5,e<=5}': 'Syria',
#  '(taiwan|taipei|formosa|^(?!.*peo)(?=.*rep).*china){i<=5,d<=5,e<=5}': 'Taiwan',
#  '(tajik){i<=5,d<=5,e<=5}': 'Tajikistan',
#  '(tanzania){i<=5,d<=5,e<=5}': 'Tanzania',
#  '(thailand|\\\\bsiam){i<=5,d<=5,e<=5}': 'Thailand',
#  '(^(?=.*leste).*timor|^(?=.*east).*timor){i<=5,d<=5,e<=5}': 'Timor-Leste',
#  '(togo){i<=5,d<=5,e<=5}': 'Togo',
#  '(tokelau){i<=5,d<=5,e<=5}': 'Tokelau',
#  '(tonga){i<=5,d<=5,e<=5}': 'Tonga',
#  '(trinidad|tobago){i<=5,d<=5,e<=5}': 'Trinidad & Tobago',
#  '(tunisia){i<=5,d<=5,e<=5}': 'Tunisia',
#  '(turkey){i<=5,d<=5,e<=5}': 'Turkey',
#  '(turkmen){i<=5,d<=5,e<=5}': 'Turkmenistan',
#  '(turks){i<=5,d<=5,e<=5}': 'Turks & Caicos Islands',
#  '(tuscany){i<=5,d<=5,e<=5}': 'Tuscany',
#  '(tuvalu){i<=5,d<=5,e<=5}': 'Tuvalu',
#  '(two.?sicilies){i<=5,d<=5,e<=5}': 'Two Sicilies',
#  '(^(?=.*\\\\bu\\\\.?\\\\s?s).*virgin|^(?=.*states).*virgin){i<=5,d<=5,e<=5}': 'U.S. Virgin Islands',
#  '(uganda){i<=5,d<=5,e<=5}': 'Uganda',
#  '(ukrain){i<=5,d<=5,e<=5}': 'Ukraine',
#  '(emirates|^u\\\\.?a\\\\.?e\\\\.?$|united.?arab.?em){i<=5,d<=5,e<=5}': 'United Arab Emirates',
#  '(united.arab.republic){i<=5,d<=5,e<=5}': 'United Arab Republic',
#  '(united.?kingdom|britain|^u\\\\.?k\\\\.?$){i<=5,d<=5,e<=5}': 'United Kingdom',
#  '(united.province.ca){i<=5,d<=5,e<=5}': 'United Province CA',
#  '(united.?states\\\\b(?!.*islands)|\\\\bu\\\\.?s\\\\.?a\\\\.?\\\\b|^\\\\s*u\\\\.?s\\\\.?\\\\b(?!.*islands)){i<=5,d<=5,e<=5}': 'United States',
#  '(minor.?outlying.?is){i<=5,d<=5,e<=5}': 'United States Minor Outlying Islands (the)',
#  '(uruguay){i<=5,d<=5,e<=5}': 'Uruguay',
#  '(uzbek){i<=5,d<=5,e<=5}': 'Uzbekistan',
#  '(vanuatu|new.?hebrides){i<=5,d<=5,e<=5}': 'Vanuatu',
#  '(holy.?see|vatican|papal.?st){i<=5,d<=5,e<=5}': 'Vatican City',
#  '(venezuela){i<=5,d<=5,e<=5}': 'Venezuela',
#  '(^(?!south)(?!republic).*viet.?nam(?!.*south)|democratic.republic.of.vietnam|socialist.republic.of.viet.?nam|north.viet.?nam|viet.?nam.north){i<=5,d<=5,e<=5}': 'Vietnam',
#  '(futuna|wallis){i<=5,d<=5,e<=5}': 'Wallis & Futuna',
#  '(western.sahara){i<=5,d<=5,e<=5}': 'Western Sahara',
#  '(w(ue|ü)rttemburg){i<=5,d<=5,e<=5}': 'Wuerttemburg',
#  '(w.rtemberg){i<=5,d<=5,e<=5}': 'Würtemberg',
#  '(^(?!.*arab)(?!.*north)(?!.*sana)(?!.*peo)(?!.*dem)(?!.*south)(?!.*aden)(?!.*\\\\bp\\\\.?d\\\\.?r).*yemen){i<=5,d<=5,e<=5}': 'Yemen',
#  '(^(?=.*arab).*yemen|^(?=.*north).*yemen|^(?=.*sana).*yemen){i<=5,d<=5,e<=5}': 'Yemen Arab Republic',
#  '(^(?=.*peo).*yemen|^(?!.*rep)(?=.*dem).*yemen|^(?=.*south).*yemen|^(?=.*aden).*yemen|^(?=.*\\\\bp\\\\.?d\\\\.?r).*yemen){i<=5,d<=5,e<=5}': "Yemen People's Republic",
#  '(yugoslavia){i<=5,d<=5,e<=5}': 'Yugoslavia',
#  '(zambia|northern.?rhodesia){i<=5,d<=5,e<=5}': 'Zambia',
#  '(zanzibar){i<=5,d<=5,e<=5}': 'Zanzibar',
#  '(zimbabwe|^(?!.*northern).*rhodesia){i<=5,d<=5,e<=5}': 'Zimbabwe'}

# %%
# spacy.require_gpu()
nlp = spacy.load('en_core_web_md')

# %%
nlp.max_length = max(corpus['text'].str.len())

# %%
nlp.add_pipe('merge_entities')
# Out:
# <function spacy.pipeline.functions.merge_entities(doc: spacy.tokens.doc.Doc)>

# %%
def include_token(x, stopwords):
    latin_character = x.is_ascii
    not_punctuation = not x.is_punct 
    not_digit = not x.is_digit
    not_stopword = x.lemma_ not in stopwords
    length_over_one = (len(x.lemma_) > 1)
    include = latin_character and not_punctuation and not_digit and not_stopword and length_over_one
    return include

# %%
def custom_tokenizer(doc, stopwords):
    doc = nlp(doc, disable = ['parser'])
    tokens = [x.lemma_ for x in doc if include_token(x, stopwords)]
    return tokens

# %%
docs = nlp.pipe(corpus['text'], batch_size = 400, disable = ['parser'], n_process = 8)

# %%
# client = Client(n_workers = 4)

# %%
tokenized_docs = [custom_tokenizer(doc, stopwords) for doc in docs]

# %%
spacy.explain('GPE')
# Out:
# 'Countries, cities, states'

# %%
vocab = []

# %%
for doc in docs:
    for token in doc:
        if token.ent_type_ == 'GPE':
            vocab.append(token.lemma_)

# %%
vocab = list(set(vocab))

# %%
vocab
# Out:
# ['Badan',
#  'Comoros',
#  'Gaza strip',
#  'the U. S. Administration',
#  'Indo Africa',
#  'Alexandria',
#  'India Thailand',
#  'Phnom Penh',
#  'Veracruz',
#  'Costa  \n\nRica',
#  'Masjid',
#  'Mauritian Republic',
#  'the Democratic Republic of Afghanistan',
#  'the Republic of Oriental del Uruguay',
#  'South Asia',
#  'post-kyoto',
#  'Prime mini14th',
#  'Shahjehanabad',
#  'Wangari Maathai',
#  'the Republice of Venezuela',
#  'Methacillin',
#  'Peopleâ\x80\x99s',
#  'north versus',
#  'Sidiropoulos',
#  'Arab Republic',
#  'Vishakapatnam',
#  'Â\x90',
#  'Iccland',
#  'Satyagrah',
#  'Dalit',
#  'the Republic of Botswana',
#  'the Centre of russian Glory',
#  'Handpumps',
#  'Wexford',
#  'Radioisopes',
#  'the Centre for Rural and Industrial Development Studies',
#  'Lichtenstein',
#  'Rangpur',
#  'the United States America',
#  'Ladakh',
#  'Fredericton',
#  'Bicholim',
#  'the People\x92s Republic of Bangladesh',
#  'Chavan',
#  'Badshah Khan',
#  'Locomotives',
#  'Shantiniketan',
#  'Trivandrum',
#  'Tehran(Iran',
#  'Kirti',
#  'Joint Indo-British',
#  'South \n\n    Africa',
#  'Crimea',
#  'Niger Republic',
#  'ukrain',
#  'Kirloskarvadi',
#  'Muzaffrabad',
#  'Kamalpur',
#  'Wolof',
#  'Indo-yugoslav Science and Technology Agreement',
#  'the Republic of  \n\nKorea',
#  'the Kingdom of Tonga',
#  'North-South Engagement',
#  'minsk',
#  'Q.C.',
#  'non-evacuee',
#  'Siolim',
#  'Elysee',
#  'Pathalganga',
#  'Cabo Delgado',
#  'TURKEY',
#  'Socialist Republic of Viet Nam',
#  'RKEY',
#  'UNITED KINGDOM GUINEA',
#  'just\x97until',
#  'Republic of Serbia',
#  'MC',
#  'Jurica',
#  'pro-west',
#  'Kabul Bank',
#  'Jhanjhara',
#  'ragas',
#  'Rhode Island',
#  'Samoens',
#  'Signing of Wye River MOU',
#  'saudi ARABIA INDIA INDONESIA',
#  'the Saharawi Arab Democratic Republic',
#  'African Union',
#  'BELGRADE',
#  'Limassol',
#  'Dar-Es-Salaam',
#  'Guwahati',
#  'Macmohan',
#  'Karzai',
#  'Mysuru',
#  'Gadwals',
#  'La ridge area',
#  'Sofia &Tripoli',
#  'Sharm El-Sheikh Summit',
#  'Karamzin',
#  'joint Voyage',
#  'Joint India-',
#  '8',
#  'Republic of Lithuania',
#  'the Socialist Republic of Romania of Shri L. N. Mishra',
#  'Manasarovar Lake',
#  'kinÃ',
#  'Wester',
#  'the United Kingdom of',
#  'Lansdowne',
#  'Sundarpur',
#  'Gilgit',
#  'St. Vincent',
#  'Rajkot',
#  'philippines',
#  'Indo-Soviet Cooperation in Power Development',
#  'Centre',
#  'Dagestan',
#  'North-south',
#  'PSC',
#  'Shangri',
#  'Lokmanya',
#  'Aryabhata',
#  'Upper Nile State',
#  'sewa',
#  'Inmol',
#  'Diego Garcia',
#  'SFU',
#  'Prambanan Temple',
#  'Knee',
#  'East Khasi',
#  'Dhabiya',
#  'Warsaw Republic',
#  'Manesar',
#  'Husseiniwala',
#  'the Northern Province of Sri Lanka',
#  'Fasie',
#  'Belize',
#  'Sister-City',
#  'Kasaoka city',
#  'Bihar Mica',
#  'lankan',
#  'Angarsk',
#  'bilingual',
#  'Jujuy',
#  'Cheonan',
#  'Pearl',
#  'Vyjayanthimala',
#  'iAsia Africa',
#  'Ruzizi',
#  'poonch',
#  'longlaste Indo-Vietnam',
#  'the Abu Dhabi',
#  'Eelam',
#  'the Republic of South Vietnam',
#  '\x93vietnam',
#  'Suharto',
#  'Palermo',
#  'the Argentin Republic',
#  'Agrement',
#  'Malaya',
#  'the Kingdom of Spain',
#  '-saminar',
#  'West Africa-',
#  'METI',
#  'Raxaul',
#  'manila',
#  'Belgaum city',
#  'Bombay State',
#  'Hyecho',
#  'South Bank',
#  'Prinoe',
#  'the Soviet Scientists',
#  'Nicobar',
#  "Shri Chavan's",
#  'Srinagar Muzaffarabad',
#  'German Democratic Republic',
#  '& Singapore',
#  'N.B.C.C.',
#  'Ujjwala',
#  'the Republic of Public Services',
#  'sortium',
#  'Palestinien',
#  'Nepalgunj',
#  'Tenn.',
#  'MD',
#  'dear Soviet Friends',
#  'NDC',
#  'Goiania',
#  'Arria',
#  'Nonaligned',
#  'Northern Korea',
#  'Afghanistan UAE',
#  'russia',
#  'the West Bengal Land Reforms (Amendment) Act',
#  'anti-india',
#  'Nuremburg',
#  'this Special Administrative Region of China',
#  'North  bengal',
#  'Tutikorin',
#  'Pokhran',
#  'Panchvati',
#  'Putrajaya',
#  'the Kingdom for indian Haj',
#  'the Republic of Maldives for Avoidance',
#  'Baba Kalyani',
#  'West asia',
#  'Conterence',
#  'mangnesia',
#  'Nairobi',
#  'Kishnikov',
#  'Port \n\nLouis',
#  'Mughal',
#  'San Martin',
#  'MALAYSIA UNITED KINGDOM',
#  'INDIA CAYMAN',
#  'Mahanadi',
#  'Wroclaw',
#  'So Paulo',
#  'Gujjar',
#  'the CONTADORA States',
#  'Quebec',
#  'the U. S. S. R.',
#  'Brickfields',
#  'the soviet Delegation',
#  'Cyprus,',
#  'Jharkhand',
#  'INDIA TURKEY SAUDI ARABIA CENTRAL AFRICAN REPUBLIC',
#  'York',
#  'the Republic of Benin',
#  'Rajivji',
#  'nonasian state',
#  'Navroz',
#  'Diamniadio',
#  'Chinghai',
#  'hill States',
#  'Bananas',
#  'Jamica',
#  'Indo-Seychelles',
#  'the Kingdom of',
#  'Readymade',
#  'SSP Patiala',
#  'Taba',
#  'Makhachkala',
#  'Francophone Africa',
#  'South India',
#  'Reunion Islands',
#  'India Republic of Korea',
#  'ignfa-Dehradun',
#  'E. North-East Frontier',
#  'Цboth',
#  'Riyasi Block',
#  'the Republic of Algeria',
#  'Indo-Yugoslavia Cultural Cooperation Programme',
#  'India Tanzania',
#  'Hijaz',
#  'Dimona',
#  'St. Kitts',
#  'the West Seti',
#  'portuguese',
#  'Dar-es-salaam',
#  'India Maldives',
#  'Bosnia Herzegovina',
#  'Frankfort',
#  'Cape Town',
#  'New-Delhi',
#  'Sunil',
#  'I.T.',
#  'Japa',
#  'the Republic of the',
#  'the Hellenic Republic',
#  'Mombassa',
#  'Poland',
#  'South Lorea',
#  'Malaprabha',
#  'South China',
#  'Ferozepur',
#  'Iran',
#  'PALESTINE',
#  'Hsaibah',
#  'Kashmiries',
#  'Sunil Gupta',
#  'Republic of Mauritius',
#  'Khulna \nDistrict',
#  'cricket',
#  'Haripur',
#  'Tadjikstan',
#  'Radon',
#  'Republic of South Yemen',
#  'Haa',
#  'Turkestan',
#  'the Republic of Iceland',
#  'MAURITIUS',
#  'african States',
#  'Sambalpur',
#  'EAST BENGAL',
#  'endc/42',
#  'Creek',
#  'the west bank',
#  'Republic of Peru',
#  'dhaka',
#  'Indo -French',
#  'timbuktu',
#  'Punjabi',
#  'Amanullah Khan',
#  'Moldavia',
#  'Mishmi Hills District',
#  'Ladli',
#  'Deutsche Marks',
#  'Miami',
#  'Sudoimport',
#  'Bibipur village',
#  'know"-I',
#  '\x93India',
#  'Tbk',
#  'Kashmir Sector',
#  'Naga Hills-Tuensang Area Act',
#  'mission',
#  'Sohna',
#  'BrahMos',
#  'Ungalil',
#  'Karakul',
#  'the Republic of Mozambique Joaquim Alberto Chissano',
#  'Unan Province',
#  'Keran',
#  'Mavalyannong',
#  'the Republic of Kenya',
#  'Accra',
#  'Dawei',
#  'Trusteeship',
#  'Canberra',
#  'Papua Guinea',
#  'Kacperczyk',
#  'Parbatipur',
#  'Orlando',
#  'Ranchi-West',
#  'Washington, D.C',
#  'Nangade',
#  'post-potsdam',
#  'Dolia',
#  'Air Indias Kanishka',
#  'Tin Bigha',
#  'Chairs',
#  'singapore',
#  'Indo-US Special Forces',
#  'NEW ZEALAND USA',
#  'Chakradharpur',
#  'Maoist',
#  'CHINA',
#  'the United Nationssuffers',
#  'Dehradun',
#  'Beit Iba',
#  'Churia',
#  'the Bolivarian Republic of Venezuela',
#  'Paktika',
#  'Rio de Janeiro',
#  'Feenza',
#  'the Luoyong Buddhist Temple',
#  'the United Republic of Tanzania',
#  'Baalu',
#  'Karawang',
#  'BJD',
#  'FEDERAL REPUBLIC of',
#  'Capital City',
#  'Nandgaon',
#  'U.S.A.',
#  "South West Africa Peoples' Organisation",
#  'Romania',
#  'the United Nation',
#  'Sakalin-3',
#  'South Bengal',
#  'New Delhi Declaration on',
#  'the Socialist Republic of Romania',
#  'SAUDI ARABIA USA',
#  'Chad',
#  'North-eastern States',
#  'Fazilka',
#  'Gujrati',
#  'Soyabean',
#  'Girona',
#  'arunachal',
#  'Nehru Centre',
#  'Farangistan',
#  'the Socialist RePublic of Vietnam',
#  'Tipu',
#  'rega rd',
#  'Hainan province',
#  'Arlindo Chinaglia',
#  'Yamuna',
#  'Afgnanistan',
#  'New South Wales',
#  'the SOVIET UNION & EASTERN EUROPE',
#  'Mannar',
#  'Vigeland',
#  'Kushaha',
#  'Ednardo',
#  'north-South',
#  'ZAIRE',
#  'National Concord',
#  'the Republic of Romania',
#  'Venkateshwara Hatcheries',
#  'ANGUILLA',
#  'Kingdom of Cambodia',
#  'Development Peoples Republic of China',
#  'West-Bengal Government',
#  'Bhudan Lands',
#  'Mira Behn',
#  'joy.~',
#  'Johore',
#  'West indies.-relation',
#  'Indo-USSR Cooperation in Agriculture',
#  'Profealong',
#  'lPU',
#  'Maldives',
#  'Lyonpo Khandu Wangchuk',
#  'Krung Thep',
#  'the Republic of Indonesia H.E',
#  'Bled',
#  'Azad Kashmir',
#  'Kingdom of Belgium',
#  'Ethio',
#  'South Iran',
#  'dar-essalaam',
#  'Madam Boniver',
#  'Malik',
#  'Narayanganj',
#  'the Bering States',
#  'Puncak',
#  'St. Olav',
#  'U.S.',
#  'W. Germany',
#  'D.P.R. Korea',
#  'Medico',
#  'Shaanxi',
#  'Hkamti',
#  'Norman',
#  'north Eastern',
#  'Hormuz',
#  'Salzburg',
#  'South Sandwich Islands',
#  'Sri Lankan',
#  'Kirghizstan',
#  'Kayathar',
#  'Stavanger',
#  'the United Republic',
#  'South Rhodesia',
#  'Paling',
#  'Suleimanki',
#  'Achuvely Industrial Zone',
#  'west    Bengal',
#  'Kirtan',
#  'I.A.C.',
#  'the United Kingdom Regulations',
#  'Godhra',
#  'the Republic of India Republic',
#  'PG69outer',
#  'Uttar',
#  'Gaborone',
#  'New Delhi Sun Yuxi',
#  'Perlis',
#  'central Asian States',
#  'grow India',
#  'Catalysits',
#  'Panch',
#  'Kyrgy[stan',
#  'twochina',
#  'Minnesota',
#  'Umbilo Park',
#  'Hong',
#  'Khabarovsk',
#  'Shonar Bangla',
#  'Hinterland States',
#  'East Timor',
#  'Confindustria',
#  '\x93golden Handshakes\x94',
#  'Khoramshahr',
#  'Kiswahili',
#  'Basilica',
#  'Kalyani',
#  'nonaligned',
#  'monwya city',
#  'India Republic of India',
#  'Severodvinsk',
#  'Thorium',
#  'Punta Cana',
#  'Nehru Uiniversity',
#  'millennia',
#  'Switzerland.-An',
#  'Nandimarg',
#  'Nadimarg',
#  'Malacca',
#  'New Indo-Egyptian Trade Arrangement',
#  'IDA-8',
#  'Panjab',
#  'Popular Republic',
#  'Republic of Vietnam',
#  'Ghazni',
#  'IBSA',
#  'Jahalpur',
#  'Sindh Province',
#  'Braithwaitte',
#  'Gulf of Aden',
#  'nuclearweapon States',
#  'Goalundo',
#  'Indo-US Collaborative',
#  'Guangzhou',
#  'Muchena',
#  'Uttarakhand',
#  'Univ',
#  'Bolnano',
#  '.1973',
#  'Commerciale',
#  'Lubricants',
#  'South Vietnam',
#  'Jealgora',
#  'the U. N. Mission',
#  'Sorbonne',
#  'Indo-Iran Regions',
#  'North Korea',
#  'the Arctic States',
#  'Bricks',
#  'Nuwara Eliya',
#  'Kodiyettam',
#  'Sovexportfilm',
#  'Jaunpur',
#  'Kazakhistan',
#  'Virenbhai',
#  'Coimbra',
#  'Cracow',
#  'Presiden',
#  'Malaya Peninsula',
#  'Paracas',
#  'pool+',
#  'non-commonwealth',
#  'Islamia',
#  'Kholba',
#  'Cannes',
#  'Takhar province',
#  'Montreuxâ\x80\x99',
#  'Roskilde',
#  'Travancore State',
#  'Ahilaya',
#  'the Kingdom of Swaziland',
#  'Aarambh',
#  'W ZEALAND INDIA USA CENTRAL AFRICAN REPUBLIC',
#  'Tennesee',
#  'Vadinar',
#  'Prasadam',
#  'Ivorie',
#  'Kirloskar',
#  'Westminster',
#  'Sharonkhola',
#  'East come',
#  'Karanataka',
#  'the Heads of State',
#  'TEPCO',
#  'Foodgrain',
#  'nairobi',
#  'the Sumdorong Chu Valley',
#  'Sujatha Singh',
#  'Maharashtra',
#  'Expotextil',
#  'Joint Indo-american',
#  'Harlingen',
#  'NASSCOM',
#  'Danang City',
#  'Nacala',
#  'five States',
#  'new \n\n    Delhi',
#  'Sweden',
#  'Knozville',
#  'DRDL',
#  'Madhubala',
#  'the Saskatchewan Province',
#  'New York City',
#  'K.K.Handique',
#  'ROMANIA',
#  'Italy India',
#  'Ondangwa, Namibia',
#  'Sri Somnath Chatterjee',
#  'MALAYSIA',
#  'herbin(china',
#  'Pasighat',
#  'Delphi',
#  'Soune',
#  'Brussels',
#  'Dahej',
#  'INDIA SENEGAL',
#  'Republic of Senegal',
#  'Shanghai',
#  'Budapest â\x80\x93',
#  'the Republic of Pakistan',
#  'North-South Cooperation',
#  'Guantanamo',
#  'Cologne',
#  'Indo-Belgium',
#  'Bangladesh Brazil',
#  'Nametkina',
#  'Bagan',
#  'Limeking',
#  'Gambia',
#  'the Kingdom of Nigeria',
#  'Ans Myanmar',
#  'lt',
#  'Lida',
#  'Bridgetown',
#  'Great Nicobar',
#  'Namibia1',
#  'Ariyalai',
#  'Socialist Republic of Vietnam',
#  'Indo-U.S. Agreements sign',
#  'PMC+Mekong Ganga',
#  'Huascaran',
#  'Special Commonwealth',
#  'functioningâ\x80\x94how',
#  'Investment~',
#  'Federal Republic of Cameroons',
#  'Lautaka',
#  'IRAQ',
#  'Banda',
#  'nepal',
#  'Balochs',
#  'New York',
#  'Mathematics',
#  'RMANY',
#  'Shahrukh Khan',
#  'Bi',
#  'Agusta Westland',
#  'the Chagai Hills',
#  'mumbaikar',
#  'Federative Republic',
#  'MOSCOW',
#  'Whitefield',
#  'Porlamar',
#  'IndoChina States',
#  'the Republic of India    Government of the Republic of Italy',
#  'Bangabandhuwhich',
#  'Jaynagar',
#  'the Republic of lndia',
#  'turkey',
#  'the Republic of Poland on',
#  'Majuli',
#  'San Remo',
#  "south\n\n\n\nAfrica's",
#  'Washim',
#  'Elk Grove',
#  'Signing of Indo-Swedish Bilateral Textile Agreement',
#  'Mai gulfaam',
#  'the Republic of Albania',
#  'Saljhandi',
#  'Bhasha',
#  'the United States Defence',
#  'Malayasia',
#  'Aayog',
#  'IVORY COAST',
#  'Fatehpur',
#  'Hunza',
#  'ESTONIA',
#  'Madam Kyaing Kyaing',
#  'Makati',
#  'Agusta',
#  'New Orleans',
#  'Hua Hin',
#  'hungary',
#  'Bellville',
#  'Zhuhai',
#  'Madhava',
#  'Adelaide',
#  'Mapuca',
#  'Saipan',
#  'North Rhine',
#  'Reykiavik',
#  'the \n\n    Republic of Tajikistan',
#  'Montreux',
#  'Nahaleen',
#  'saidwach',
#  'Madam Pohamba',
#  'U.S. States',
#  'Dhubri',
#  'UNITED STATES',
#  'the Islamic Republic of Pakistan',
#  'Kohinoor',
#  'Indo-Yemen Cooperation',
#  'the Bhambore Hills of Kohlu',
#  'the United Repblic of Tanzania',
#  'Pricipal',
#  'kyrghyz',
#  'Masala Bond',
#  'the RUSSIAN FEDERATION on',
#  '\x93so\x94',
#  'Ababa',
#  'Port Blair',
#  'the United States Commodity Futures Trading Commission',
#  'l.46',
#  'Sisula',
#  'Trignometry',
#  'Rivatex',
#  'LIPA Valley',
#  'Tibet-China',
#  'Robermi',
#  'Singapores',
#  'Novemebr',
#  'Syria',
#  'Mekong Ganga-Cooperation',
#  'Nippon',
#  'Gorkhas',
#  'Sravanabelagola',
#  'Janeiro',
#  'NETHERLAND',
#  'Cotonou',
#  'G-5',
#  'Yamunanager',
#  'Banaskantha',
#  'co110',
#  'North Eastern Sri Lanka',
#  'Peopleâ\x80\x99s Republic of China',
#  'Hussain',
#  'Kohalpur',
#  'Kyrgyz Republic',
#  'french franc',
#  'Neem',
#  'North-West',
#  'Somlia',
#  'States',
#  'Chille',
#  'Austrlia',
#  'Venkys Hatcheries',
#  'the Czech Republic on Defence Cooperation',
#  'Mahabharata',
#  'Hailakhandi',
#  'the City of the Hague',
#  'Guam Island',
#  'Quemoy',
#  'tonga',
#  'the Republic of Kiribati',
#  'Space',
#  'Belguim',
#  'Jericho',
#  'Cairns',
#  'Dar es Salam',
#  'Mahawa',
#  'Hannover',
#  'Peoplesâ\x80\x99 Republic of Korea',
#  'Haryana State',
#  'DoT',
#  'the City of Delhi',
#  'E. WEST ASIA',
#  'ussr',
#  'Everest',
#  'Papua New',
#  'West Bengal Smt',
#  'Sri lankan',
#  'Tafe',
#  'allIndia',
#  'Kerala',
#  'Kabaddi',
#  'South Africa a Republic',
#  'Jiribam',
#  'the Republic of India for Cooperation',
#  'Singh Chatha',
#  'El Bekri',
#  'Bumthang',
#  'Mogadishu',
#  'the Central Building',
#  '\x93in',
#  'Owambo',
#  "East Pakistan's",
#  'Onthachchimadam',
#  'Navajivan',
#  'Joint Indo-Romanian Commission for Economic',
#  'Dhoti',
#  'Alitalia',
#  'MONGOLIA KOREA',
#  'Bucharest',
#  'the Republic of Cyprus Tassos Papadopoulos',
#  'Singh Ghatowar',
#  'Chapeau',
#  'the Republic of Nauru',
#  'C.C.I.R.',
#  'Federal Democratic Republic',
#  'barbado',
#  'Sri Lankaâ\x80\x93in',
#  'Sammelan',
#  'the Republic of Belarus on',
#  'North Countries',
#  'Groundwater',
#  'nirvana',
#  'Island States',
#  'San-francisco',
#  'Now York',
#  'Air-India',
#  'Rafah',
#  'Pesticides',
#  'Raipur',
#  'subjects:(i',
#  'alleged Landing',
#  'March',
#  'Sialkot',
#  'Mtwara',
#  'Hyderbad',
#  'Thailands',
#  'NEW Delhi',
#  'U.N.C.T.A.D. II',
#  'the german States',
#  'Bombay',
#  'Sumatra',
#  'Premadasa',
#  'p.a.',
#  'Israel Maj',
#  'Kankesanthurai',
#  'Malaga',
#  'north bengal',
#  'Tura',
#  'Rulership',
#  'Combodia',
#  'NIPI',
#  'Apostle',
#  'Argentia',
#  'Rio 2007',
#  'Piprahwa',
#  'the State of Maharashtra',
#  'Idaho',
#  'new States',
#  'FCCC',
#  'Joint Indo-Czechoslovak Communique',
#  'indiabase',
#  'Maharaja run jit Singh',
#  'south Africas',
#  'Fujian Province',
#  'the \n\nRepublic of India',
#  'Bina',
#  'advocac',
#  'India Tourist',
#  'each Republic Day',
#  'the States of Latin America',
#  'Chandni',
#  'south\n\n\n\nAfrica',
#  'the Peoples Democratic Republic of Yemen',
#  'flotilla',
#  'Urbanization',
#  'Visakhapatanam',
#  'Haqqani',
#  'COLOMBIA',
#  'Sewa',
#  'Muhmangedaamaapkodenepadenge',
#  'Asturias',
#  'North Cachar Hills',
#  'Photo Korea',
#  'Northern Province',
#  'Sofala',
#  'White Republic',
#  'N.A.',
#  'the Rajya Sabha',
#  'District Jail Malir',
#  'Kandahar',
#  'Transylvania',
#  'Ottawa',
#  'INDIA SENEGAL USA',
#  'L',
#  'Democratic Republic on Drug Demand Reduction and Prevention of Illicit Trafficking',
#  'Roorkee',
#  'Aguada',
#  'Nowshera',
#  'Dijibouti',
#  'Baltic States',
#  'the United Arab Emiartes',
#  'Camboida',
#  'â\x80\x98Ganga',
#  'Suvale Islands',
#  'Telegraphs',
#  "India Finland's",
#  'Yunnan Province',
#  'Nathula',
#  'Natha',
#  'Fujian',
#  'Khwalahilung village',
#  'Developing Countries',
#  'Uttama',
#  'Belgrade',
#  'Giani Zail Singh',
#  'the Gazette of',
#  'Indo-Indonesia',
#  'the French Republic on Cooperation between',
#  'the Kingdom of Spain on',
#  'Percival',
#  'Peoples Republic of China',
#  'Prabhat',
#  'Indo-USSR Trade',
#  'EI',
#  'North Africa Economic Conference',
#  'Irak',
#  'Jan.-Feb',
#  'Bapu',
#  'Senegal',
#  'Dosvidanya',
#  'Republic of Korea on',
#  'Satyam',
#  'Ghana Empire',
#  'tamanna',
#  'Khemkaran',
#  'Inhambane',
#  'Esfahan',
#  'Bt',
#  'Belgaum',
#  'Vanuatu',
#  'Mya',
#  'United Kingdom',
#  '\x93arabic',
#  'the Province of Nova Scotia',
#  'Karnataka Building',
#  'Turku',
#  'Parbatpur',
#  'Santa Fe',
#  'MaleNew Delhi',
#  'Nurek',
#  'Asean',
#  'Brigadier',
#  'Nyasaland',
#  'Aganwadi',
#  'Yamethin',
#  'Indo-U.K. Talks',
#  'Panditji',
#  'Se',
#  'North Lakhimpur',
#  'â\x80\x99',
#  'the NETHERLANDS REPUBLIC of SINGAPORE',
#  'DPR Korea',
#  'Indo-Sudan',
#  'Mindelo',
#  'Lusambo',
#  'Syria Arab Republic of Feb 16, 1978',
#  'Sixtyfive States',
#  'Mozambigue',
#  'Sri-Lanka',
#  'Kyzgystan',
#  '---------------------------------------------------------------------------------------------6',
#  'Duterte',
#  'the Federative Republic of Brazil',
#  'South-East Asia11-',
#  'Winterthur',
#  'the Netherlands Indies',
#  'Operation Raahat',
#  'Narita',
#  'Arikamedu',
#  'Balaton Fured',
#  'Mahiga',
#  'the Republic of Azerbaijan',
#  'F. Africa',
#  'Libya',
#  'Praia',
#  'Okurusu',
#  'Thrissur',
#  'bollywood',
#  'Indo-yugoslav Trade : Protocol sign\n\n\n\n\nTalks',
#  'Kempton',
#  'Bhaktapur',
#  'circumlunar',
#  'Shlok',
#  "Prince Norodom's",
#  'countries\x97the United States',
#  'pargana',
#  'Riau',
#  'Hitech',
#  'BULGARIA',
#  'East  Bengal',
#  'the Qinghai Province',
#  'Zawkhatar',
#  'Elephanta',
#  'Bagota',
#  'Granby',
#  'Kushiara',
#  'saudi Arabia',
#  'the States of Arunachal Pradesh',
#  'St. Brandon Islands',
#  'Gyeonggi province',
#  'Hong \n\nKong',
#  'portugal',
#  'Achaigmori',
#  'Indo-USSR',
#  'Banglabandh',
#  'Hon Kong',
#  'the Northern Province',
#  'MALI',
#  'Manica province',
#  'C.I.',
#  'Syracuse',
#  'SOUTH AFRICA INDONESIA',
#  'Houston',
#  'Jwalamukhi',
#  'gujarat',
#  'North Eastern China',
#  'Tinsukia',
#  'North-South economic',
#  'the Socialist Republic',
#  'Kreditanstalt \n\n    Fur Wiederaufbau',
#  'Katyusha',
#  'Kashmir State of',
#  'Pausa',
#  'BJP',
#  'Pacific Zone',
#  ...]

# %%
import pycountry

# %%
[{c.name:token for token in vocab if c.name in token} for c in pycountry.countries]
# Out:
# [{'Aruba': 'Aruba'},
#  {'Afghanistan': 'Indo-Afghanistan'},
#  {'Angola': 'the Peoples Republic of Angola'},
#  {'Anguilla': 'Anguilla'},
#  {},
#  {'Albania': 'Albania'},
#  {},
#  {'United Arab Emirates': 'Indo-United Arab Emirates Joint Commission on Economic, scientific and Technical Cooperation'},
#  {'Argentina': 'initiative\x97Argentina'},
#  {'Armenia': 'the Republic of Armenia'},
#  {},
#  {'Antarctica': 'Antarctica'},
#  {},
#  {},
#  {'Australia': 'the Republic of Australia'},
#  {'Austria': 'Austria'},
#  {'Azerbaijan': 'Azerbaijan Republic'},
#  {'Burundi': 'Burundi'},
#  {'Belgium': 'Belgium'},
#  {'Benin': 'Benin'},
#  {},
#  {'Burkina Faso': 'Burkina Faso'},
#  {'Bangladesh': 'Bangladesh Meghalaya'},
#  {'Bulgaria': 'Indo-Bulgaria Joint Press Statement'},
#  {'Bahrain': 'the Kingdom of Bahrain for'},
#  {'Bahamas': 'Bahamas'},
#  {'Bosnia and Herzegovina': 'Bosnia and Herzegovina on'},
#  {},
#  {'Belarus': 'Belarus'},
#  {'Belize': 'Belizean'},
#  {'Bermuda': 'Bermuda'},
#  {},
#  {'Brazil': 'the Republic of Indiaand the Government of the Federative Republic of Brazil'},
#  {'Barbados': 'Barbados'},
#  {'Brunei Darussalam': 'Brunei Darussalam'},
#  {'Bhutan': 'Bhutan-China'},
#  {},
#  {'Botswana': 'Botswana Gaborone'},
#  {},
#  {'Canada': 'the Province of Ontario of Canada'},
#  {},
#  {'Switzerland': 'Switzerland'},
#  {'Chile': 'Chile'},
#  {'China': 'the Republic of India                             Peoples Republic of China'},
#  {},
#  {'Cameroon': 'Republic of Cameroon'},
#  {},
#  {'Congo': 'D.R. Congo'},
#  {'Cook Islands': 'Cook Islands'},
#  {'Colombia': 'Colombia'},
#  {'Comoros': 'Comoros'},
#  {},
#  {'Costa Rica': 'the Republic of Costa Rica'},
#  {'Cuba': 'the Republic of Cuba'},
#  {},
#  {},
#  {},
#  {'Cyprus': 'Cyprus-Greece-Turkey'},
#  {},
#  {'Germany': 'the Federal Republic of \n\n   \n\n   Germany'},
#  {'Djibouti': 'the Republic of Djibouti'},
#  {'Dominica': 'the Dominican Republic'},
#  {'Denmark': 'Denmark'},
#  {'Dominican Republic': 'the Dominican Republic'},
#  {'Algeria': 'the Republic of the democratic and Popular Republic of Algeria'},
#  {'Ecuador': 'Ecuador'},
#  {'Egypt': 'Egypt'},
#  {'Eritrea': 'India-Eritrea'},
#  {},
#  {'Spain': 'Spain'},
#  {'Estonia': 'Estonia'},
#  {'Ethiopia': 'Ethiopia'},
#  {'Finland': 'Finland Norway'},
#  {'Fiji': 'the Republic of Fiji on'},
#  {},
#  {'France': 'Franceville Gabon'},
#  {},
#  {},
#  {'Gabon': 'Indo-Gabon'},
#  {'United Kingdom': 'the United Kingdom'},
#  {'Georgia': 'South Georgia'},
#  {'Guernsey': 'Guernsey'},
#  {'Ghana': 'the Republic of Ghana'},
#  {'Gibraltar': 'Gibraltar'},
#  {'Guinea': 'Papua New Guinea on Cooperation'},
#  {'Guadeloupe': 'Guadeloupe'},
#  {'Gambia': 'India-Gambia Business Forum'},
#  {'Guinea-Bissau': 'Guinea-Bissau'},
#  {'Equatorial Guinea': 'the Republic of Equatorial Guinea'},
#  {'Greece': 'Cyprus-Greece-Turkey'},
#  {'Grenada': 'Grenada'},
#  {'Greenland': 'Greenland'},
#  {'Guatemala': 'El Salvador Guatemala'},
#  {},
#  {'Guam': 'Guam'},
#  {'Guyana': 'the Cooperative Republic of Guyana'},
#  {'Hong Kong': 'Hong Kongregarding'},
#  {},
#  {'Honduras': 'the Republic of Honduras'},
#  {'Croatia': 'the Republic of Croatia'},
#  {'Haiti': 'Haiti'},
#  {'Hungary': 'Hungary'},
#  {'Indonesia': 'the friendly Republic of Indonesia'},
#  {},
#  {'India': 'India Rwanda'},
#  {},
#  {'Ireland': 'Enterprise Ireland'},
#  {},
#  {'Iraq': 'IndiaIraq'},
#  {'Iceland': 'Iceland'},
#  {'Israel': 'Israel'},
#  {'Italy': 'Italy Czechoslovakia'},
#  {'Jamaica': 'Jamaica'},
#  {'Jersey': 'New Jersey'},
#  {'Jordan': 'Indo-Jordan Joint Trade and Economic Committee'},
#  {'Japan': 'East Japan'},
#  {'Kazakhstan': 'the Republic of Kazakhstan Republic of India'},
#  {'Kenya': 'Republic of Kenya'},
#  {'Kyrgyzstan': 'India-Kyrgyzstan'},
#  {'Cambodia': 'the Kingdom of Cambodia'},
#  {'Kiribati': 'Kiribati'},
#  {},
#  {},
#  {'Kuwait': 'Indo-Kuwait'},
#  {},
#  {'Lebanon': 'North Lebanon'},
#  {'Liberia': 'Liberia'},
#  {'Libya': 'New Libya'},
#  {},
#  {'Liechtenstein': 'Liechtenstein'},
#  {'Sri Lanka': 'IndoSri Lanka'},
#  {'Lesotho': 'the Kingdom of Lesotho'},
#  {'Lithuania': 'Lithuania'},
#  {'Luxembourg': 'Luxembourg'},
#  {'Latvia': 'Latvia'},
#  {'Macao': 'Macao'},
#  {},
#  {'Morocco': 'the Kingdom of Morocco'},
#  {'Monaco': 'Monaco'},
#  {},
#  {'Madagascar': 'Republic of Madagascar'},
#  {'Maldives': 'Indo-Maldives'},
#  {'Mexico': 'MRI Mexico'},
#  {'Marshall Islands': 'the Marshall Islands'},
#  {},
#  {'Mali': 'District Jail, Malir'},
#  {'Malta': 'Malta'},
#  {'Myanmar': 'Indo-Myanmar'},
#  {'Montenegro': 'the Republic of Montenegro'},
#  {'Mongolia': 'Mongolia'},
#  {},
#  {'Mozambique': 'the Republic of\nMozambique'},
#  {'Mauritania': 'the Islamic Republic of Mauritania'},
#  {'Montserrat': 'Montserrat'},
#  {'Martinique': 'Martinique'},
#  {'Mauritius': 'the Republic of Mauritius'},
#  {'Malawi': 'Lake Malawi'},
#  {'Malaysia': 'the Malaysian Railways'},
#  {'Mayotte': 'Mayotte'},
#  {'Namibia': 'SWAPO Namibia'},
#  {'New Caledonia': 'New Caledonia'},
#  {'Niger': 'Federal Republic of Nigeria'},
#  {},
#  {'Nigeria': 'Federal Republic of Nigeria'},
#  {'Nicaragua': 'Nicaragua'},
#  {'Niue': 'Niue'},
#  {'Netherlands': 'the Netherlands Centre'},
#  {'Norway': 'Oslo Norway'},
#  {'Nepal': 'Nepal a Republic'},
#  {'Nauru': 'Nauru'},
#  {'New Zealand': 'New Zealand PM'},
#  {'Oman': 'Oman Aden'},
#  {'Pakistan': 'India Pakistan'},
#  {'Panama': 'Panama'},
#  {'Pitcairn': 'Pitcairn'},
#  {'Peru': 'the Republic of Peru'},
#  {'Philippines': 'the Republic of the Philippines'},
#  {'Palau': 'Palau'},
#  {'Papua New Guinea': 'Papua New Guinea on Cooperation'},
#  {'Poland': 'Republic of Poland'},
#  {'Puerto Rico': 'Puerto Rico'},
#  {},
#  {'Portugal': 'Portugal Cyprus'},
#  {'Paraguay': 'the Republic of Paraguay'},
#  {},
#  {},
#  {'Qatar': 'Indo-Qatari Joint Committee'},
#  {},
#  {'Romania': 'Joint Indo-Romanian Commission'},
#  {'Russian Federation': 'the Russian Federation'},
#  {'Rwanda': 'India Rwanda'},
#  {'Saudi Arabia': 'the Saudi Arabia'},
#  {'Sudan': 'First Indo-Sudanese Trade Agreement sign'},
#  {'Senegal': 'Senegals'},
#  {'Singapore': 'Singaporeand'},
#  {},
#  {},
#  {},
#  {'Solomon Islands': 'Solomon Islands'},
#  {},
#  {'El Salvador': 'El Salvador Guatemala'},
#  {'San Marino': 'the Republic of San Marino'},
#  {'Somalia': 'the Federal Republic of Somalia'},
#  {},
#  {'Serbia': 'the Republic of Serbia'},
#  {'South Sudan': "South Sudan's"},
#  {},
#  {'Suriname': 'Suriname'},
#  {'Slovakia': 'Slovakia'},
#  {'Slovenia': 'the Republic of Slovenia'},
#  {'Sweden': 'the Kingdom of Sweden'},
#  {},
#  {},
#  {'Seychelles': 'the Republic of Seychelles for Cooperation'},
#  {'Syrian Arab Republic': "the Syrian Arab Republic'"},
#  {},
#  {'Chad': 'Chadbet'},
#  {'Togo': 'Togoland'},
#  {'Thailand': 'the Kingdom of Thailand'},
#  {'Tajikistan': 'the Republic of Tajikistan'},
#  {'Tokelau': 'Tokelau'},
#  {'Turkmenistan': 'the Republic of Turkmenistan'},
#  {},
#  {'Tonga': 'the Republic of Tonga'},
#  {},
#  {'Tunisia': 'Tunisia'},
#  {'Turkey': 'Cyprus-Greece-Turkey'},
#  {'Tuvalu': 'Tuvalu'},
#  {},
#  {},
#  {'Uganda': 'Ugandan'},
#  {'Ukraine': 'Ukraine'},
#  {},
#  {'Uruguay': 'Montevideo, Uruguay'},
#  {'United States': 'United States-India'},
#  {'Uzbekistan': 'the Republic of Uzbekistan (State'},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {'Viet Nam': 'South Viet Nam'},
#  {'Vanuatu': 'the Republic of Vanuatu'},
#  {},
#  {'Samoa': 'Western Samoa'},
#  {'Yemen': 'Yemen Indo'},
#  {'South Africa': 'the Republic of India                             the Republic of South Africa'},
#  {'Zambia': 'the Zambian Railways'},
#  {'Zimbabwe': 'Zimbabwe'}]

# %%
pd.Series(vocab).replace('\\s{2,}', ' ', regex = True).replace(ccode_dict, regex = True).to_list()
# Out:
# ['Badan',
#  'Comoros',
#  'Gaza strip',
#  'the U. S. Administration',
#  'Indo Africa',
#  'Alexandria',
#  'India Thailand',
#  'Phnom Penh',
#  'Veracruz',
#  'Costa Rica',
#  'Masjid',
#  'Mauritian Republic',
#  'the Democratic Republic of Afghanistan',
#  'the Republic of Oriental del Uruguay',
#  'South Asia',
#  'post-kyoto',
#  'Prime mini14th',
#  'Shahjehanabad',
#  'Wangari Maathai',
#  'the Republice of Venezuela',
#  'Methacillin',
#  'Peopleâ\x80\x99s',
#  'north versus',
#  'Sidiropoulos',
#  'Arab Republic',
#  'Vishakapatnam',
#  'Â\x90',
#  'Iccland',
#  'Satyagrah',
#  'Dalit',
#  'the Republic of Botswana',
#  'the Centre of Russian Glory',
#  'Handpumps',
#  'Wexford',
#  'Radioisopes',
#  'the Centre for Rural and Industrial Development Studies',
#  'Lichtenstein',
#  'Rangpur',
#  'the United States America',
#  'Ladakh',
#  'Fredericton',
#  'Bicholim',
#  'the People\x92s Republic of Bangladesh',
#  'Chavan',
#  'Badshah Khan',
#  'Locomotives',
#  'Shantiniketan',
#  'Trivandrum',
#  'Tehran(Iran',
#  'Kirti',
#  'Joint Indo-British',
#  'South Africa',
#  'Crimea',
#  'Niger Republic',
#  'Ukraine',
#  'Kirloskarvadi',
#  'Muzaffrabad',
#  'Kamalpur',
#  'Wolof',
#  'Indo-yugoslav Science and Technology Agreement',
#  'the Republic of Korea',
#  'the Kingdom of Tonga',
#  'North-South Engagement',
#  'minsk',
#  'Q.C.',
#  'non-evacuee',
#  'Siolim',
#  'Elysee',
#  'Pathalganga',
#  'Cabo Delgado',
#  'TURKEY',
#  'Socialist Republic of Viet Nam',
#  'RKEY',
#  'UNITED KINGDOM GUINEA',
#  'just\x97until',
#  'Republic of Serbia',
#  'MC',
#  'Jurica',
#  'pro-west',
#  'Kabul Bank',
#  'Jhanjhara',
#  'ragas',
#  'Rhode Island',
#  'Samoens',
#  'Signing of Wye River MOU',
#  'saudi ARABIA INDIA INDONESIA',
#  'the Saharawi Arab Democratic Republic',
#  'African Union',
#  'BELGRADE',
#  'Limassol',
#  'Dar-Es-Salaam',
#  'Guwahati',
#  'Macmohan',
#  'Karzai',
#  'Mysuru',
#  'Gadwals',
#  'La ridge area',
#  'Sofia &Tripoli',
#  'Sharm El-Sheikh Summit',
#  'Karamzin',
#  'joint Voyage',
#  'Joint India-',
#  '8',
#  'Republic of Lithuania',
#  'the Socialist Republic of Romania of Shri L. N. Mishra',
#  'Manasarovar Lake',
#  'kinÃ',
#  'Wester',
#  'the United Kingdom of',
#  'Lansdowne',
#  'Sundarpur',
#  'Gilgit',
#  'St. Vincent',
#  'Rajkot',
#  'Philippines',
#  'Indo-Soviet Cooperation in Power Development',
#  'Centre',
#  'Dagestan',
#  'North-south',
#  'PSC',
#  'Shangri',
#  'Lokmanya',
#  'Aryabhata',
#  'Upper Nile State',
#  'sewa',
#  'Inmol',
#  'Diego Garcia',
#  'SFU',
#  'Prambanan Temple',
#  'Knee',
#  'East Khasi',
#  'Dhabiya',
#  'Warsaw Republic',
#  'Manesar',
#  'Husseiniwala',
#  'the Northern Province of Sri Lanka',
#  'Fasie',
#  'Belize',
#  'Sister-City',
#  'Kasaoka city',
#  'Bihar Mica',
#  'lankan',
#  'Angarsk',
#  'bilingual',
#  'Jujuy',
#  'Cheonan',
#  'Pearl',
#  'Vyjayanthimala',
#  'iAsia Africa',
#  'Ruzizi',
#  'poonch',
#  'longlaste Indo-Vietnam',
#  'the Abu Dhabi',
#  'Eelam',
#  'the Republic of South Vietnam',
#  'Vietnam',
#  'Suharto',
#  'Palermo',
#  'the Argentin Republic',
#  'Agrement',
#  'Malaya',
#  'the Kingdom of Spain',
#  '-saminar',
#  'West Africa-',
#  'METI',
#  'Raxaul',
#  'manila',
#  'Belgaum city',
#  'Bombay State',
#  'Hyecho',
#  'South Bank',
#  'Prinoe',
#  'the Soviet Scientists',
#  'Nicobar',
#  "Shri Chavan's",
#  'Srinagar Muzaffarabad',
#  'German Democratic Republic',
#  '& Singapore',
#  'N.B.C.C.',
#  'Ujjwala',
#  'the Republic of Public Services',
#  'sortium',
#  'Palestinien',
#  'Nepalgunj',
#  'Tenn.',
#  'MD',
#  'dear Soviet Friends',
#  'NDC',
#  'Goiania',
#  'Arria',
#  'Nonaligned',
#  'Northern Korea',
#  'Afghanistan UAE',
#  'Russia',
#  'the West Bengal Land Reforms (Amendment) Act',
#  'anti-India',
#  'Nuremburg',
#  'this Special Administrative Region of China',
#  'North bengal',
#  'Tutikorin',
#  'Pokhran',
#  'Panchvati',
#  'Putrajaya',
#  'the Kingdom for Indian Haj',
#  'the Republic of Maldives for Avoidance',
#  'Baba Kalyani',
#  'West asia',
#  'Conterence',
#  'mangnesia',
#  'Nairobi',
#  'Kishnikov',
#  'Port Louis',
#  'Mughal',
#  'San Martin',
#  'MALAYSIA UNITED KINGDOM',
#  'INDIA CAYMAN',
#  'Mahanadi',
#  'Wroclaw',
#  'So Paulo',
#  'Gujjar',
#  'the CONTADORA States',
#  'Quebec',
#  'the U. S. S. R.',
#  'Brickfields',
#  'the soviet Delegation',
#  'Cyprus,',
#  'Jharkhand',
#  'INDIA TURKEY SAUDI ARABIA CENTRAL AFRICAN REPUBLIC',
#  'York',
#  'the Republic of Benin',
#  'Rajivji',
#  'nonasian state',
#  'Navroz',
#  'Diamniadio',
#  'Chinghai',
#  'hill States',
#  'Bananas',
#  'Jamica',
#  'Indo-Seychelles',
#  'the Kingdom of',
#  'Readymade',
#  'SSP Patiala',
#  'Taba',
#  'Makhachkala',
#  'Francophone Africa',
#  'South India',
#  'Reunion Islands',
#  'India Republic of Korea',
#  'ignfa-Dehradun',
#  'E. North-East Frontier',
#  'Цboth',
#  'Riyasi Block',
#  'the Republic of Algeria',
#  'Indo-Yugoslavia Cultural Cooperation Programme',
#  'India Tanzania',
#  'Hijaz',
#  'Dimona',
#  'St. Kitts',
#  'the West Seti',
#  'portuguese',
#  'Dar-es-salaam',
#  'India Maldives',
#  'Bosnia Herzegovina',
#  'Frankfort',
#  'Cape Town',
#  'New-Delhi',
#  'Sunil',
#  'I.T.',
#  'Japa',
#  'the Republic of the',
#  'the Hellenic Republic',
#  'Mombassa',
#  'Poland',
#  'South Lorea',
#  'Malaprabha',
#  'South China',
#  'Ferozepur',
#  'Iran',
#  'PALESTINE',
#  'Hsaibah',
#  'Kashmiries',
#  'Sunil Gupta',
#  'Republic of Mauritius',
#  'Khulna District',
#  'cricket',
#  'Haripur',
#  'Tadjikstan',
#  'Radon',
#  'Republic of South Yemen',
#  'Haa',
#  'Turkestan',
#  'the Republic of Iceland',
#  'MAURITIUS',
#  'african States',
#  'Sambalpur',
#  'EAST BENGAL',
#  'endc/42',
#  'Creek',
#  'the Palestinian Territories',
#  'Republic of Peru',
#  'dhaka',
#  'Indo -French',
#  'timbuktu',
#  'Punjabi',
#  'Amanullah Khan',
#  'Moldavia',
#  'Mishmi Hills District',
#  'Ladli',
#  'Deutsche Marks',
#  'Miami',
#  'Sudoimport',
#  'Bibipur village',
#  'know"-I',
#  '\x93India',
#  'Tbk',
#  'Kashmir Sector',
#  'Naga Hills-Tuensang Area Act',
#  'mission',
#  'Sohna',
#  'BrahMos',
#  'Ungalil',
#  'Karakul',
#  'the Republic of Mozambique Joaquim Alberto Chissano',
#  'Unan Province',
#  'Keran',
#  'Mavalyannong',
#  'the Republic of Kenya',
#  'Accra',
#  'Dawei',
#  'Trusteeship',
#  'Canberra',
#  'Papua Guinea',
#  'Kacperczyk',
#  'Parbatipur',
#  'Orlando',
#  'Ranchi-West',
#  'Washington, D.C',
#  'Nangade',
#  'post-potsdam',
#  'Dolia',
#  'Air Indias Kanishka',
#  'Tin Bigha',
#  'Chairs',
#  'Singapore',
#  'Indo-US Special Forces',
#  'NEW ZEALAND USA',
#  'Chakradharpur',
#  'Maoist',
#  'CHINA',
#  'the United Nationssuffers',
#  'Dehradun',
#  'Beit Iba',
#  'Churia',
#  'the Bolivarian Republic of Venezuela',
#  'Paktika',
#  'Rio de Janeiro',
#  'Feenza',
#  'the Luoyong Buddhist Temple',
#  'the United Republic of Tanzania',
#  'Baalu',
#  'Karawang',
#  'BJD',
#  'FEDERAL REPUBLIC of',
#  'Capital City',
#  'Nandgaon',
#  'U.S.A.',
#  "South West Africa Peoples' Organisation",
#  'Romania',
#  'the United Nation',
#  'Sakalin-3',
#  'South Bengal',
#  'New Delhi Declaration on',
#  'the Socialist Republic of Romania',
#  'SAUDI ARABIA USA',
#  'Chad',
#  'North-eastern States',
#  'Fazilka',
#  'Gujrati',
#  'Soyabean',
#  'Girona',
#  'arunachal',
#  'Nehru Centre',
#  'Farangistan',
#  'the Socialist RePublic of Vietnam',
#  'Tipu',
#  'rega rd',
#  'Hainan province',
#  'Arlindo Chinaglia',
#  'Yamuna',
#  'Afgnanistan',
#  'New South Wales',
#  'the SOVIET UNION & EASTERN EUROPE',
#  'Mannar',
#  'Vigeland',
#  'Kushaha',
#  'Ednardo',
#  'north-South',
#  'ZAIRE',
#  'National Concord',
#  'the Republic of Romania',
#  'Venkateshwara Hatcheries',
#  'ANGUILLA',
#  'Kingdom of Cambodia',
#  'Development Peoples Republic of China',
#  'West-Bengal Government',
#  'Bhudan Lands',
#  'Mira Behn',
#  'joy.~',
#  'Johore',
#  'West indies.-relation',
#  'Indo-USSR Cooperation in Agriculture',
#  'Profealong',
#  'lPU',
#  'Maldives',
#  'Lyonpo Khandu Wangchuk',
#  'Krung Thep',
#  'the Republic of Indonesia H.E',
#  'Bled',
#  'Azad Kashmir',
#  'Kingdom of Belgium',
#  'Ethio',
#  'South Iran',
#  'dar-essalaam',
#  'Madam Boniver',
#  'Malik',
#  'Narayanganj',
#  'the Bering States',
#  'Puncak',
#  'St. Olav',
#  'U.S.',
#  'W. Germany',
#  'D.P.R. Korea',
#  'Medico',
#  'Shaanxi',
#  'Hkamti',
#  'Norman',
#  'north Eastern',
#  'Hormuz',
#  'Salzburg',
#  'South Sandwich Islands',
#  'Sri Lankan',
#  'Kirghizstan',
#  'Kayathar',
#  'Stavanger',
#  'the United Republic',
#  'South Rhodesia',
#  'Paling',
#  'Suleimanki',
#  'Achuvely Industrial Zone',
#  'west Bengal',
#  'Kirtan',
#  'I.A.C.',
#  'the United Kingdom Regulations',
#  'Godhra',
#  'the Republic of India Republic',
#  'PG69outer',
#  'Uttar',
#  'Gaborone',
#  'New Delhi Sun Yuxi',
#  'Perlis',
#  'central Asian States',
#  'grow India',
#  'Catalysits',
#  'Panch',
#  'Kyrgy[stan',
#  'China',
#  'Minnesota',
#  'Umbilo Park',
#  'Hong',
#  'Khabarovsk',
#  'Shonar Bangla',
#  'Hinterland States',
#  'East Timor',
#  'Confindustria',
#  '\x93golden Handshakes\x94',
#  'Khoramshahr',
#  'Kiswahili',
#  'Basilica',
#  'Kalyani',
#  'nonaligned',
#  'monwya city',
#  'India Republic of India',
#  'Severodvinsk',
#  'Thorium',
#  'Punta Cana',
#  'Nehru Uiniversity',
#  'millennia',
#  'Switzerland.-An',
#  'Nandimarg',
#  'Nadimarg',
#  'Malacca',
#  'New Indo-Egyptian Trade Arrangement',
#  'IDA-8',
#  'Panjab',
#  'Popular Republic',
#  'Republic of Vietnam',
#  'Ghazni',
#  'IBSA',
#  'Jahalpur',
#  'Sindh Province',
#  'Braithwaitte',
#  'Gulf of Aden',
#  'nuclearweapon States',
#  'Goalundo',
#  'Indo-US Collaborative',
#  'Guangzhou',
#  'Muchena',
#  'Uttarakhand',
#  'Univ',
#  'Bolnano',
#  '.1973',
#  'Commerciale',
#  'Lubricants',
#  'South Vietnam',
#  'Jealgora',
#  'the U. N. Mission',
#  'Sorbonne',
#  'Indo-Iran Regions',
#  'North Korea',
#  'the Arctic States',
#  'Bricks',
#  'Nuwara Eliya',
#  'Kodiyettam',
#  'Sovexportfilm',
#  'Jaunpur',
#  'Kazakhistan',
#  'Virenbhai',
#  'Coimbra',
#  'Cracow',
#  'Presiden',
#  'Malaya Peninsula',
#  'Paracas',
#  'pool+',
#  'non-commonwealth',
#  'Islamia',
#  'Kholba',
#  'Cannes',
#  'Takhar province',
#  'Montreuxâ\x80\x99',
#  'Roskilde',
#  'Travancore State',
#  'Ahilaya',
#  'the Kingdom of Swaziland',
#  'Aarambh',
#  'W ZEALAND INDIA USA CENTRAL AFRICAN REPUBLIC',
#  'Tennesee',
#  'Vadinar',
#  'Prasadam',
#  'Ivorie',
#  'Kirloskar',
#  'Westminster',
#  'Sharonkhola',
#  'East come',
#  'Karanataka',
#  'the Heads of State',
#  'TEPCO',
#  'Foodgrain',
#  'nairobi',
#  'the Sumdorong Chu Valley',
#  'Sujatha Singh',
#  'Maharashtra',
#  'Expotextil',
#  'Joint Indo-american',
#  'Harlingen',
#  'NASSCOM',
#  'Danang City',
#  'Nacala',
#  'five States',
#  'new Delhi',
#  'Sweden',
#  'Knozville',
#  'DRDL',
#  'Madhubala',
#  'the Saskatchewan Province',
#  'New York City',
#  'K.K.Handique',
#  'ROMANIA',
#  'Italy India',
#  'Ondangwa, Namibia',
#  'Sri Somnath Chatterjee',
#  'MALAYSIA',
#  'China',
#  'Pasighat',
#  'Delphi',
#  'Soune',
#  'Brussels',
#  'Dahej',
#  'INDIA SENEGAL',
#  'Republic of Senegal',
#  'Shanghai',
#  'Budapest â\x80\x93',
#  'the Republic of Pakistan',
#  'North-South Cooperation',
#  'Guantanamo',
#  'Cologne',
#  'Indo-Belgium',
#  'Bangladesh Brazil',
#  'Nametkina',
#  'Bagan',
#  'Limeking',
#  'Gambia',
#  'the Kingdom of Nigeria',
#  'Ans Myanmar',
#  'lt',
#  'Lida',
#  'Bridgetown',
#  'Great Nicobar',
#  'Namibia1',
#  'Ariyalai',
#  'Socialist Republic of Vietnam',
#  'Indo-U.S. Agreements sign',
#  'PMC+Mekong Ganga',
#  'Huascaran',
#  'Special Commonwealth',
#  'functioningâ\x80\x94how',
#  'Investment~',
#  'Federal Republic of Cameroons',
#  'Lautaka',
#  'IRAQ',
#  'Banda',
#  'Nepal',
#  'Balochs',
#  'New York',
#  'Mathematics',
#  'RMANY',
#  'Shahrukh Khan',
#  'Bi',
#  'Agusta Westland',
#  'the Chagai Hills',
#  'mumbaikar',
#  'Federative Republic',
#  'MOSCOW',
#  'Whitefield',
#  'Porlamar',
#  'IndoChina States',
#  'the Republic of India Government of the Republic of Italy',
#  'Bangabandhuwhich',
#  'Jaynagar',
#  'the Republic of lndia',
#  'Turkey',
#  'the Republic of Poland on',
#  'Majuli',
#  'San Remo',
#  "south Africa's",
#  'Washim',
#  'Elk Grove',
#  'Signing of Indo-Swedish Bilateral Textile Agreement',
#  'Mai gulfaam',
#  'the Republic of Albania',
#  'Saljhandi',
#  'Bhasha',
#  'the United States Defence',
#  'Malayasia',
#  'Aayog',
#  'IVORY COAST',
#  'Fatehpur',
#  'Hunza',
#  'ESTONIA',
#  'Madam Kyaing Kyaing',
#  'Makati',
#  'Agusta',
#  'New Orleans',
#  'Hua Hin',
#  'Hungary',
#  'Bellville',
#  'Zhuhai',
#  'Madhava',
#  'Adelaide',
#  'Mapuca',
#  'Saipan',
#  'North Rhine',
#  'Reykiavik',
#  'the Republic of Tajikistan',
#  'Montreux',
#  'Nahaleen',
#  'saidwach',
#  'Madam Pohamba',
#  'U.S. States',
#  'Dhubri',
#  'UNITED STATES',
#  'the Islamic Republic of Pakistan',
#  'Kohinoor',
#  'Indo-Yemen Cooperation',
#  'the Bhambore Hills of Kohlu',
#  'the United Repblic of Tanzania',
#  'Pricipal',
#  'kyrghyz',
#  'Masala Bond',
#  'the RUSSIAN FEDERATION on',
#  '\x93so\x94',
#  'Ababa',
#  'Port Blair',
#  'the United States Commodity Futures Trading Commission',
#  'l.46',
#  'Sisula',
#  'Trignometry',
#  'Rivatex',
#  'LIPA Valley',
#  'Tibet-China',
#  'Robermi',
#  'Singapores',
#  'Novemebr',
#  'Syria',
#  'Mekong Ganga-Cooperation',
#  'Nippon',
#  'Gorkhas',
#  'Sravanabelagola',
#  'Janeiro',
#  'NETHERLAND',
#  'Cotonou',
#  'G-5',
#  'Yamunanager',
#  'Banaskantha',
#  'co110',
#  'North Eastern Sri Lanka',
#  'Peopleâ\x80\x99s Republic of China',
#  'Hussain',
#  'Kohalpur',
#  'Kyrgyz Republic',
#  'french franc',
#  'Neem',
#  'North-West',
#  'Somlia',
#  'States',
#  'Chille',
#  'Austrlia',
#  'Venkys Hatcheries',
#  'the Czech Republic on Defence Cooperation',
#  'Mahabharata',
#  'Hailakhandi',
#  'the City of the Hague',
#  'Guam Island',
#  'Quemoy',
#  'Tonga',
#  'the Republic of Kiribati',
#  'Space',
#  'Belguim',
#  'Jericho',
#  'Cairns',
#  'Dar es Salam',
#  'Mahawa',
#  'Hannover',
#  'Peoplesâ\x80\x99 Republic of Korea',
#  'Haryana State',
#  'DoT',
#  'the City of Delhi',
#  'E. WEST ASIA',
#  'Russia',
#  'Everest',
#  'Papua New',
#  'West Bengal Smt',
#  'Sri lankan',
#  'Tafe',
#  'allIndia',
#  'Kerala',
#  'Kabaddi',
#  'South Africa a Republic',
#  'Jiribam',
#  'the Republic of India for Cooperation',
#  'Singh Chatha',
#  'El Bekri',
#  'Bumthang',
#  'Mogadishu',
#  'the Central Building',
#  '\x93in',
#  'Owambo',
#  "East Pakistan's",
#  'Onthachchimadam',
#  'Navajivan',
#  'Joint Indo-Romanian Commission for Economic',
#  'Dhoti',
#  'Alitalia',
#  'MONGOLIA KOREA',
#  'Bucharest',
#  'the Republic of Cyprus Tassos Papadopoulos',
#  'Singh Ghatowar',
#  'Chapeau',
#  'the Republic of Nauru',
#  'C.C.I.R.',
#  'Federal Democratic Republic',
#  'barbado',
#  'Sri Lankaâ\x80\x93in',
#  'Sammelan',
#  'the Republic of Belarus on',
#  'North Countries',
#  'Groundwater',
#  'nirvana',
#  'Island States',
#  'San-francisco',
#  'Now York',
#  'Air-India',
#  'Rafah',
#  'Pesticides',
#  'Raipur',
#  'subjects:(i',
#  'alleged Landing',
#  'March',
#  'Sialkot',
#  'Mtwara',
#  'Hyderbad',
#  'Thailands',
#  'NEW Delhi',
#  'U.N.C.T.A.D. II',
#  'the german States',
#  'Bombay',
#  'Sumatra',
#  'Premadasa',
#  'p.a.',
#  'Israel Maj',
#  'Kankesanthurai',
#  'Malaga',
#  'north bengal',
#  'Tura',
#  'Rulership',
#  'Combodia',
#  'NIPI',
#  'Apostle',
#  'Argentia',
#  'Rio 2007',
#  'Piprahwa',
#  'the State of Maharashtra',
#  'Idaho',
#  'new States',
#  'FCCC',
#  'Slovakia Communique',
#  'Indiabase',
#  'Maharaja run jit Singh',
#  'south Africas',
#  'Fujian Province',
#  'the Republic of India',
#  'Bina',
#  'advocac',
#  'India Tourist',
#  'each Republic Day',
#  'the States of Latin America',
#  'Chandni',
#  'south Africa',
#  'the Peoples Democratic Republic of Yemen',
#  'flotilla',
#  'Urbanization',
#  'Visakhapatanam',
#  'Haqqani',
#  'COLOMBIA',
#  'Sewa',
#  'Muhmangedaamaapkodenepadenge',
#  'Asturias',
#  'North Cachar Hills',
#  'Photo Korea',
#  'Northern Province',
#  'Sofala',
#  'White Republic',
#  'N.A.',
#  'the Rajya Sabha',
#  'District Jail Malir',
#  'Kandahar',
#  'Transylvania',
#  'Ottawa',
#  'INDIA SENEGAL USA',
#  'L',
#  'Democratic Republic on Drug Demand Reduction and Prevention of Illicit Trafficking',
#  'Roorkee',
#  'Aguada',
#  'Nowshera',
#  'Dijibouti',
#  'Baltic States',
#  'the United Arab Emiartes',
#  'Camboida',
#  'â\x80\x98Ganga',
#  'Suvale Islands',
#  'Telegraphs',
#  "India Finland's",
#  'Yunnan Province',
#  'Nathula',
#  'Natha',
#  'Fujian',
#  'Khwalahilung village',
#  'Developing Countries',
#  'Uttama',
#  'Belgrade',
#  'Giani Zail Singh',
#  'the Gazette of',
#  'Indo-Indonesia',
#  'the French Republic on Cooperation between',
#  'the Kingdom of Spain on',
#  'Percival',
#  'Peoples Republic of China',
#  'Prabhat',
#  'Indo-USSR Trade',
#  'EI',
#  'North Africa Economic Conference',
#  'Irak',
#  'Jan.-Feb',
#  'Bapu',
#  'Senegal',
#  'Dosvidanya',
#  'Republic of Korea on',
#  'Satyam',
#  'Ghana Empire',
#  'tamanna',
#  'Khemkaran',
#  'Inhambane',
#  'Esfahan',
#  'Bt',
#  'Belgaum',
#  'Vanuatu',
#  'Mya',
#  'United Kingdom',
#  '\x93arabic',
#  'the Province of Nova Scotia',
#  'Karnataka Building',
#  'Turku',
#  'Parbatpur',
#  'Santa Fe',
#  'MaleNew Delhi',
#  'Nurek',
#  'Asean',
#  'Brigadier',
#  'Nyasaland',
#  'Aganwadi',
#  'Yamethin',
#  'Indo-U.K. Talks',
#  'Panditji',
#  'Se',
#  'North Lakhimpur',
#  'â\x80\x99',
#  'the NETHERLANDS REPUBLIC of SINGAPORE',
#  'DPR Korea',
#  'Indo-Sudan',
#  'Mindelo',
#  'Lusambo',
#  'Syria Arab Republic of Feb 16, 1978',
#  'Sixtyfive States',
#  'Mozambigue',
#  'Sri-Lanka',
#  'Kyzgystan',
#  '---------------------------------------------------------------------------------------------6',
#  'Duterte',
#  'the Federative Republic of Brazil',
#  'South-East Asia11-',
#  'Winterthur',
#  'the Netherlands Indies',
#  'Operation Raahat',
#  'Narita',
#  'Arikamedu',
#  'Balaton Fured',
#  'Mahiga',
#  'the Republic of Azerbaijan',
#  'F. Africa',
#  'Libya',
#  'Praia',
#  'Okurusu',
#  'Thrissur',
#  'bollywood',
#  'Indo-yugoslav Trade : Protocol sign Talks',
#  'Kempton',
#  'Bhaktapur',
#  'circumlunar',
#  'Shlok',
#  "Prince Norodom's",
#  'countries\x97the United States',
#  'pargana',
#  'Riau',
#  'Hitech',
#  'BULGARIA',
#  'East Bengal',
#  'the Qinghai Province',
#  'Zawkhatar',
#  'Elephanta',
#  'Bagota',
#  'Granby',
#  'Kushiara',
#  'saudi Arabia',
#  'the States of Arunachal Pradesh',
#  'St. Brandon Islands',
#  'Gyeonggi province',
#  'Hong Kong',
#  'Portugal',
#  'Achaigmori',
#  'Indo-USSR',
#  'Banglabandh',
#  'Hon Kong',
#  'the Northern Province',
#  'MALI',
#  'Manica province',
#  'C.I.',
#  'Syracuse',
#  'SOUTH AFRICA INDONESIA',
#  'Houston',
#  'Jwalamukhi',
#  'gujarat',
#  'North Eastern China',
#  'Tinsukia',
#  'North-South economic',
#  'the Socialist Republic',
#  'Kreditanstalt Fur Wiederaufbau',
#  'Katyusha',
#  'Kashmir State of',
#  'Pausa',
#  'BJP',
#  'Pacific Zone',
#  ...]

# %%
# tokenized_docs = compute(*[delayed(custom_tokenizer)(doc, country_dict, stopwords) for doc in docs])

# %%
# client.close()

# %%
#

# %% [markdown]
# Replace country names using regex and combine multiword entities identified by spaCy.

# %% [markdown]
# Remove digits, long underscores, custom stopword list, words in only one document, words that appear fewer than five times, words with one character.

# %%
# dtm = CountVectorizer()
